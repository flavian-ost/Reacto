# %% [markdown]
# # Boot
# Boot runs direcly after the device gets powered. It handles setting default states and starts the execution of the gamemanager and the menu.

# %% [markdown]
# # Main
# Main contains a loop that runs indefinetly after boot has concluded. The loop repeadetly calls the get_input() and set_output() functions.
