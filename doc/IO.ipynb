# %% [markdown]
# # Input
# The input class includes functions for updating the current input states and saves them.

# %% [markdown]
# # Output
# The output class includes functions for querying output actions and runns them in order.
